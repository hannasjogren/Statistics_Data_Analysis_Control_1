# %% [markdown]
# ## Del 1 – Teoretiska frågor

# %% [markdown]
# ### 1. Många barn tror att de blev till genom att en stork kom och lämnade dem till deras föräldrar. För att undersöka det kan vi kolla på data och det finns en graf enligt figuren nedan. Det verkar alltså finnas ett samband mellan antalet storkar och barnafödsel!? Stämmer detta påståendet? Använd begreppen ”korrelation” och ”kausalitet” i ditt svar.

# %% [markdown]
# Svar: I bilden ser vi ett spridningsdiagram som visar ett positivt samband mellan antalet storkpar och antalet födslar per år. Detta innebär att i områden där det finns fler storkar, föds det också fler barn.
#
# Men betyder det att storkar verkligen levererar barn? Nej, detta är ett exempel på korrelation men inte kausalitet.
#
# Korrelation betyder att två variabler samvarierar men det betyder inte att den ena orsakar den andra.
#
# Kausalitet innebär att en förändring i en variabel direkt orsakar en förändring i en annan.
#
# I det här fallet kan det finnas en tredje variabel som påverkar båda faktorerna. En trolig förklaring är att fler storkar observeras på landsbygden, där det också kan finnas högre födelsetal jämfört med städer. Detta kan bero på olika socioekonomiska faktorer, som att familjer på landsbygden oftare har fler barn.

# %% [markdown]
# ### 2. Din kollega som inte studerat statistik frågar dig: vad är korrelation? Förklara det för din kollega med hjälp av bilden nedan.

# %% [markdown]
# Svar: Korrelation visar sambandet mellan två variabler men betyder inte att den ena orsakar den andra.
#
# I den andra bilden ser vi en rad scatter plots som visar olika typer av samband mellan två variabler. Dessa samband kan beskrivas med korrelationskoefficienten 𝑟 som varierar mellan -1 och 1.
#
# Perfekt positiv korrelation (r=1)
# Alla punkter ligger exakt på en stigande linje.
# Exempel: Antal timmar plugg → Betyg på ett prov (högre studietid leder till bättre resultat).
#
# Stark positiv korrelation (𝑟=0.8)
# Punkten sprids lite men har fortfarande en tydlig stigande trend.
# Exempel: Längd och vikt (längre personer tenderar att väga mer).
#
# Svag positiv korrelation (𝑟=0.4)
# Det finns ett samband men det är svagt.
# Exempel: Kaffekonsumtion och produktivitet (vissa blir mer produktiva, andra inte).
#
# Ingen korrelation (𝑟=0)
# Punkterna är utspridda utan tydligt mönster.
# Exempel: Skostorlek och betyg i skolan (ingen relation mellan dessa variabler).
#
# Negativ korrelation (r=−0.8,−1)
# Samband där en ökning i en variabel leder till en minskning i den andra.
# Exempel: Ju mer någon tränar, desto lägre kroppsfettprocent har personen.

# %% [markdown]
# ### 3. Kim påstår att ”medelvärdet” är ett bättre mått än ”medianvärdet”. Håller du med Kim?

# %% [markdown]
# Svar: Medelvärdet är inte alltid bättre än medianen. Om data har extrema värden eller är skevt fördelad, är medianen ett mer rättvisande mått. Exempelvis löner på ett företag: Om chefen tjänar 10 miljoner och de anställda 30 000, kommer medellönen att vara missvisande, medan medianlönen ger en bättre bild av vad en typisk anställd tjänar.

# %% [markdown]
# ### 4. Vad används cirkeldiagram för? Ge ett exempel på vad ett företag som Spotify (eller något annat företag som du själv väljer) hade kunnat använda cirkeldiagram för.

# %% [markdown]
# Svar: Cirkeldiagram används för att visa proportioner av en helhet, vilket gör dem användbara för att visa hur något fördelar sig i procent.
#
# Exempel för Spotify:
#
# Fördelningen av lyssnare per musikgenre.
#
# Hur olika abonnemangstyper (gratis, premium, familj) fördelas bland användarna.
#
# Andel av inkomst från reklam vs prenumerationer.

# %% [markdown]
# ### 5. Vad används linjediagram för? Ge ett exempel på vad ett företag som Spotify (eller något annat företag som du själv väljer) hade kunnat använda linjediagram för.

# %% [markdown]
# Svar: Linjediagram används för att visa förändringar över tid och passar bra för att analysera trender.
#
# Exempel för Spotify:
#
# Antal aktiva användare per månad under ett år.
#
# Trender i lyssnarbeteende (exempelvis ökning av julmusik i december).
#
# Intäktsutveckling över flera kvartal.

# %% [markdown]
# ### 6. Vad används lådagram för?

# %% [markdown]
# Svar: Lådagram (boxplots) används för att visa spridning och fördelning av data, inklusive median, kvartiler och eventuella extremvärden.
#
# Användningsområden:
#
# Jämförelse av löner inom olika yrken.
#
# Analys av testresultat i en klass för att se om någon har ovanligt höga eller låga poäng.
#
# Identifiera om en dataset har många extrema värden.

# %% [markdown]
# ### 7. Antag att vikten för nyfödda barn är normalfördelad. I sverige är medelvikten för nyfödda barn 3.5 kg och standardavvikelsen 0.5 kg. Vad betyder detta rent konkret? Vad är exempelvis sannolikheten att ett barn väger över 4.5 kg eller mindre än 3 kg? Om vi kollar på 1000 nyfödda barn, hur många barn förväntar vi oss väger över 4.5 kg?

# %% [markdown]
# Svar: Bilden med normalfördelningskurvan visar hur vikten på nyfödda barn fördelas i Sverige där:
#
# Medelvärdet är 3.5 kg
#
# Standardavvikelsen är 0.5 kg
#
# Sannolikhet att väga över 4.5 kg eller mindre än 3 kg:
#
# Över 4.5 kg: Detta är +2σ från medelvärdet. Enligt normalfördelningen ligger 2.14% av befolkningen i detta intervall.
#
# Under 3 kg: Detta är −1σ från medelvärdet. Enligt normalfördelningen ligger 15.87% av befolkningen i detta intervall.
#
# Om vi kollar på 1000 nyfödda barn:
#
# 2.14% av 1000 barn = 21 barn väger över 4.5 kg
#
# 15.87% av 1000 barn = 159 barn väger mindre än 3 kg

# %% [markdown]
# ## Del 2 – Statistisk dataanalys i Python

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as st

# %%
# Background
"""
This analysis aims to understand the factors influencing employee satisfaction and their decision to stay or leave Nytto Maximerarna.
By analyzing employee data, I identify patterns and trends to provide recommendations that can improve employee well-being and reduce turnover.

Focus areas:
- Relationship between satisfaction levels and employee turnover
- Impact of working hours and project workload
- Effects of promotions and workplace accidents
- Importance of salary and department affiliation
"""
# Out:
# '\nThis analysis aims to understand the factors influencing employee satisfaction and their decision to stay or leave Nytto Maximerarna.\nBy analyzing employee data, I identify patterns and trends to provide recommendations that can improve employee well-being and reduce turnover.\n\nFocus areas:\n- Relationship between satisfaction levels and employee turnover\n- Impact of working hours and project workload\n- Effects of promotions and workplace accidents\n- Importance of salary and department affiliation\n'

# %%
# Load data Excel-file
df = pd.read_excel("HR_Employee_Data.xlsx", engine="openpyxl")

# Save data to CSV
df.to_csv("HR_Employee_Data.csv", index=False)

# Correct column name
if 'average_montly_hours' in df.columns:
    df.rename(columns={'average_montly_hours': 'average_monthly_hours'}, inplace=True)

# %%
# Basic exploration
display(df.info())
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Emp_Id                 14999 non-null  object
#  1   satisfaction_level     14999 non-null  float64
#  2   last_evaluation        14999 non-null  float64
#  3   number_project         14999 non-null  int64
#  4   average_monthly_hours  14999 non-null  int64
#  5   time_spend_company     14999 non-null  int64
#  6   Work_accident          14999 non-null  int64
#  7   left                   14999 non-null  int64
#  8   promotion_last_5years  14999 non-null  int64
#  9   Department             14999 non-null  object
#  10  salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(3)
# memory usage: 1.3+ MB
# None
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# ...

# %%
# Correlation heatmap
# Explanation: A heatmap is used to visualize the correlation between numerical variables, helping to identify key factors affecting employee turnover.
def plot_correlation_heatmap(df):
    numeric_df = df.select_dtypes(include=[np.number])  # Select only numeric columns
    plt.figure(figsize=(10,6))
    sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
    plt.title('Correlation between Variables')
    plt.show()
    
plot_correlation_heatmap(df)

# %%
# Distribution of employee satisfaction levels
# Explanation: A histogram is chosen to show the distribution of satisfaction levels across employees. This helps identify overall trends and potential dissatisfaction among staff.
plt.figure(figsize=(8,5))
sns.histplot(df['satisfaction_level'], bins=30, kde=True, color='blue')
plt.title('Distribution of Satisfaction Levels')
plt.xlabel('Satisfaction Level')
plt.ylabel('Number of Employees')
plt.show()

# %%
# Satisfaction and employee turnover
# Explanation: A boxplot is used to compare satisfaction levels between employees who stayed and those who left. This helps determine if satisfaction plays a role in turnover.
plt.figure(figsize=(8,5))
sns.boxplot(x='left', y='satisfaction_level', data=df, hue='left', palette='coolwarm', legend=False)
plt.title('Satisfaction Levels of Employees Who Stayed and Left')
plt.xlabel('Left the Company (0 = No, 1 = Yes)')
plt.ylabel('Satisfaction Level')
plt.show()

# %%
# Salary and employee turnover
# Explanation: A countplot is used to visualize how employee turnover varies by salary level. This helps in understanding if lower wages contribute to higher resignation rates.
plt.figure(figsize=(8,5))
sns.countplot(x=df['salary'], hue=df['left'], palette='coolwarm')
plt.title('Employee Turnover by Salary Level')
plt.xlabel('Salary Level')
plt.ylabel('Number of Employees')
plt.legend(title='Left the Company')
plt.show()

# %%
# Working hours and employee turnover
# Explanation: A boxplot is used to compare the distribution of working hours among employees who stayed and those who left. This helps reveal if overworking leads to higher turnover.
plt.figure(figsize=(8,5))
sns.boxplot(x='left', y='average_monthly_hours', data=df, hue='left', palette='coolwarm', legend=False)
plt.title('Average Monthly Hours and Employee Turnover')
plt.xlabel('Left the Company (0 = No, 1 = Yes)')
plt.ylabel('Average Monthly Hours')
plt.show()

# %%
# Number of projects and employee turnover
# Explanation: This boxplot compares the number of projects handled by employees who left vs those who stayed, helping to determine if excessive workload is a factor in turnover.
plt.figure(figsize=(8,5))
sns.boxplot(x='left', y='number_project', data=df, hue='left', palette='coolwarm', legend=False)
plt.title('Number of Projects and Employee Turnover')
plt.xlabel('Left the Company (0 = No, 1 = Yes)')
plt.ylabel('Number of Projects')
plt.show()

# %%
# Promotion history and employee turnover
# Explanation: A countplot visualizes how promotion history affects turnover. If employees who were not promoted in the last five years tend to leave, this highlights a need for career development policies.
plt.figure(figsize=(8,5))
sns.countplot(x=df['promotion_last_5years'], hue=df['left'], palette='coolwarm')
plt.title('Employee Turnover Based on Promotions in the Last 5 Years')
plt.xlabel('Promoted in the Last 5 Years (0 = No, 1 = Yes)')
plt.ylabel('Number of Employees')
plt.legend(title='Left the Company')
plt.show()

# %%
# Workplace accidents and employee turnover
# Explanation: This countplot helps to assess whether workplace accidents influence turnover rates.
plt.figure(figsize=(8,5))
sns.countplot(x=df['Work_accident'], hue=df['left'], palette='coolwarm')
plt.title('Employee Turnover Based on Workplace Accidents')
plt.xlabel('Workplace Accident (0 = No, 1 = Yes)')
plt.ylabel('Number of Employees')
plt.legend(title='Left the Company')
plt.show()

# %%
# Combined visualization of multiple factors affecting employee turnover using bar plots
# Explanation: The purpose of this combined visualization is to compare multiple key factors in one view to better understand their impact on employee turnover.
# By using subplots, it's possible to observe how various factors such as satisfaction levels, working hours, number of projects and salary levels are related to the likelihood of employees leaving the company.
# The use of 'hue' (left) allows us to clearly differentiate between employees who left the company (1) and those who stayed (0), making it easier to analyze the differences.
# Each of these factors is chosen based on its potential impact on turnover:
# 1. Satisfaction Level: A direct relationship with employee happiness and retention.
# 2. Monthly Hours Worked: Overwork or underwork can affect employee well-being and job satisfaction.
# 3. Number of Projects: High workload could lead to burnout and dissatisfaction, leading to turnover.
# 4. Salary Level: Employees with lower salaries might feel undervalued, leading to a higher chance of leaving.
# These visualizations offer a clear and direct way to assess how these factors interact with turnover, helping to form insights to improve employee retention.

plt.figure(figsize=(14, 10))

# 1. Satisfaction level vs Employee turnover
plt.subplot(2, 2, 1)
sns.barplot(x='left', y='satisfaction_level', data=df, hue='left', palette='coolwarm', errorbar=None)
plt.title('Satisfaction Level vs. Employee Turnover')
plt.xlabel('Left the Company (0 = No, 1 = Yes)')
plt.ylabel('Average Satisfaction Level')

# 2. Monthly hours worked vs Employee turnover
plt.subplot(2, 2, 2)
sns.barplot(x='left', y='average_monthly_hours', data=df, hue='left', palette='coolwarm', errorbar=None)
plt.title('Average Monthly Hours vs. Employee Turnover')
plt.xlabel('Left the Company (0 = No, 1 = Yes)')
plt.ylabel('Average Monthly Hours')

# 3. Number of projects vs Employee turnover
plt.subplot(2, 2, 3)
sns.barplot(x='left', y='number_project', data=df, hue='left', palette='coolwarm', errorbar=None)
plt.title('Number of Projects vs. Employee Turnover')
plt.xlabel('Left the Company (0 = No, 1 = Yes)')
plt.ylabel('Number of Projects')

# 4. Salary level vs Employee turnover
plt.subplot(2, 2, 4)
sns.countplot(x='salary', hue='left', data=df, palette='coolwarm')
plt.title('Salary Level vs. Employee Turnover')
plt.xlabel('Salary Level')
plt.ylabel('Number of Employees')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Executive Summary
summary = """
Key Insights:
- Employees with low satisfaction levels are more likely to leave the company.
- Turnover rates are higher among lower salary groups.
- Employees who work either too many or too few hours per month tend to leave more frequently.
- Employees handling more than five projects are more likely to leave, possibly due to workload stress.
- Employees who have not been promoted in five years tend to leave more often.
- Workplace accidents do not show a strong correlation with turnover.

Recommendations:
1. Implement initiatives to improve employee satisfaction, such as feedback mechanisms and work-life balance programs.
2. Review salary distribution to ensure competitive wages.
3. Optimize workload by limiting the number of projects per employee.
4. Evaluate promotion policies to encourage long-term commitment.
5. Continue monitoring and minimizing workplace accidents, even though their direct impact on turnover is minimal.
"""
print(summary)
# Out:
# Key Insights:
# - Employees with low satisfaction levels are more likely to leave the company.
# - Turnover rates are higher among lower salary groups.
# - Employees who work either too many or too few hours per month tend to leave more frequently.
# - Employees handling more than five projects are more likely to leave, possibly due to workload stress.
# - Employees who have not been promoted in five years tend to leave more often.
# - Workplace accidents do not show a strong correlation with turnover.
#
# Recommendations:
# 1. Implement initiatives to improve employee satisfaction, such as feedback mechanisms and work-life balance programs.
# 2. Review salary distribution to ensure competitive wages.
# 3. Optimize workload by limiting the number of projects per employee.
# 4. Evaluate promotion policies to encourage long-term commitment.
# 5. Continue monitoring and minimizing workplace accidents, even though their direct impact on turnover is minimal.

# %% [markdown]
# ## Del 3 - Självutvärdering

# %% [markdown]
# ### 1. Vad har varit roligast i kunskapskontrollen?

# %% [markdown]
# Det absolut roligaste i denna kunskapskontroll har varit att få möjlighet att tillämpa de statistiska metoder jag har lärt mig på ett konkret och praktiskt sätt. Att använda datavisualiseringar för att förmedla insikter och skapa en tydlig berättelse var en mycket givande upplevelse. Särskilt fascinerande var att analysera sambanden mellan faktorer som arbetstid, anställdas tillfredsställelse och deras beslut att lämna företaget. Det var också väldigt intressant att arbeta med den visuella delen – att skapa grafiska representationer av resultaten i form av boxplots, histogram och korrelationsmatriser. Genom att kombinera dessa tekniker har jag kunnat få en klarare bild av hur olika faktorer relaterar till varandra och ge rekommendationer som kan vara till nytta för ett företag som "Nytto Maximerarna". Det var verkligen tillfredsställande att kunna använda min tekniska kompetens för att bidra med värdefulla insikter som inte bara är teoretiska utan också användbara i praktiken.

# %% [markdown]
# ### 2. Vilket betyg anser du att du ska ha och varför?

# %% [markdown]
# Jag anser att jag förtjänar VG eftersom jag har genomfört en djupgående analys av personaldata genom att visualisera och tolka olika samband som påverkar personalomsättningen. Min kod är välstrukturerad och jag har använt både statistiska verktyg och visuella diagram för att presentera resultaten på ett tydligt sätt. Jag har också gett konkreta rekommendationer baserat på de insikter jag har dragit från analysen och arbetat självständigt.

# %% [markdown]
# ### 3. Vad har varit mest utmanande i arbetet och hur har du hanterat det?

# %% [markdown]
# Den största utmaningen var att korrekt tolka och visualisera sambanden mellan flera olika faktorer som nöjdhet, arbetstimmar, antal projekt samt att säkerställa att analysen inte överförenklades. Jag hanterade detta genom att systematiskt skapa och utvärdera olika typer av diagram (exempelvis boxplot, countplot och barplot) för att identifiera mönster och relationer i data. Jag har också fokuserat på att hålla koden tydlig och kommentera varje steg, vilket har hjälpt mig att reflektera över analysens relevans och riktighet.
